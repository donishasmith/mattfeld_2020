# %%
import os
from glob import glob
import pandas as pd
import numpy as np
import nipype.interfaces.afni as afni
import nipype.interfaces.fsl as fsl
import nipype.interfaces.freesurfer as fs
import nipype.interfaces.spm as spm
from nipype.algorithms.rapidart import ArtifactDetect
from nipype.interfaces.utility import Function
import nibabel as nb
import json
import nipype.interfaces.io as nio
import nipype.pipeline.engine as pe 
import nipype.interfaces.utility as util
base_dir = '/home/dsmit216/psb6351/mattfeld_2020'
work_dir = '/scratch/dsmit216/mattfeld'
func_dir = os.path.join(base_dir, f'dset/sub-021/func')
anat_dir = os.path.join(base_dir, f'dset/sub-021/anat')
fmap_dir = os.path.join(base_dir, f'dset/sub-021/fmap')
fs_dir = os.path.join(base_dir, 'derivatives', 'freesurfer')
func_json = sorted(glob(func_dir + '/*.json'))
func_files = sorted(glob(func_dir + '/*.nii.gz'))
fmap_files = sorted(glob(fmap_dir + '/*func*.nii.gz'))
anat_files = sorted(glob(anat_dir + '/*T1w*.nii.gz'))
def get_subs(func_files):
    '''Produces Name Substitutions for Each Contrast'''
    subs = []
    for curr_run in range(len(func_files)):
        subs.append(('_motion_corr%d' %curr_run, ''))
        subs.append(('_slicetime_corr%d' %curr_run, ''))
        subs.append(('_align%d' %curr_run, ''))
    return subs

def first_vol(func_files):
    if isinstance(func_files, list):
        return func_files[0]
    

def getbtthresh(medianvals):
    """Get the brightness threshold for SUSAN."""
    return [0.75*val for val in medianvals]

def getusans(inlist):
    """Return the usans at the right threshold."""
    return [[tuple([val[0],0.75*val[1]])] for val in inlist]

def get_aparc_aseg(files):
    for name in files:
        if 'aparc+aseg' in name:
            return name
    raise ValueError('aparc+aseg.mgz not found')    

slice_timing_list = [] 
for curr_json in func_json:
    curr_json_data = open(curr_json)
    curr_func_metadata = json.load(curr_json_data) 
    slice_timing_list.append(curr_func_metadata['SliceTiming'])

psb6351_wf = pe.Workflow(name='psb6351_wf')
psb6351_wf.base_dir = work_dir + f'/psb6351workdir/sub-021' 
psb6351_wf.config['execution']['use_relative_paths'] = True 

getsubs = pe.Node(Function(input_names=['func_files'],
                           output_names=['subs'],
                           function=get_subs),
                  name='getsubs')
getsubs.inputs.func_files = func_files

motion_corr = pe.MapNode(fsl.MCFLIRT(), iterfield = ['in_file'], name = 'motion_corr')
motion_corr.inputs.in_file = func_files
motion_corr.inputs.cost = 'leastsquares'
motion_corr.inputs.interpolation = 'spline'
motion_corr.inputs.save_plots= True
motion_corr.inputs.save_mats = True
motion_corr.inputs.save_rms = True
motion_corr.inputs.stats_imgs = True
motion_corr.inputs.outputtype = 'NIFTI_GZ'
motion_corr.inputs.ref_file = func_files[0]

meanfunc = pe.Node(
    interface=fsl.ImageMaths(op_string='-Tmean', suffix='_mean'),
    name='meanfunc')
psb6351_wf.connect(motion_corr,('out_file', first_vol), meanfunc, 'in_file')

meanfuncmask = pe.Node(interface=fsl.BET(mask=True,frac=0.3),name='meanfuncmask')
psb6351_wf.connect(meanfunc, 'out_file', meanfuncmask, 'in_file')

maskfunc = pe.MapNode(interface=fsl.ImageMaths(suffix='_bet', op_string='-mas'),iterfield=['in_file'],name='maskfunc')
psb6351_wf.connect(motion_corr, 'out_file', maskfunc, 'in_file')
psb6351_wf.connect(meanfuncmask, 'mask_file', maskfunc, 'in_file2')

meananat = pe.Node(
    interface=fsl.ImageMaths(in_file = anat_files[0], op_string='-Tmean', suffix='_mean'),
    name='meananat')


meananatmask = pe.Node(interface=fsl.BET(mask=True, frac=0.3),name='meananatmask')
psb6351_wf.connect(meananat, 'out_file', meananatmask, 'in_file')

maskanat = pe.MapNode(interface=fsl.ImageMaths(in_file = anat_files[0],suffix='_bet', op_string='-mas'),iterfield=['in_file'],name='maskanat')
psb6351_wf.connect(meananatmask, 'mask_file', maskanat, 'in_file2')

###############################
# ADD RAPIDART DETECTION HERE #
###############################
artifacts = pe.MapNode(ArtifactDetect(), iterfield = ['realigned_files','realignment_parameters'], name = 'artifacts')
artifacts.inputs.parameter_source = 'FSL'
artifacts.inputs.mask_type = 'spm_global'
artifacts.inputs.norm_threshold = 0.2
artifacts.inputs.use_differences = [True, False]
artifacts.inputs.zintensity_threshold = 4
psb6351_wf.connect(motion_corr, 'par_file', artifacts, 'realignment_parameters')
psb6351_wf.connect(maskfunc, 'out_file', artifacts, 'realigned_files')
psb6351_wf.connect(meanfuncmask, 'mask_file', artifacts, 'mask_file')

slicetime_corr = pe.MapNode(afni.TShift(), iterfield=['in_file','slice_timing'],name = 'slicetime_corr')
slicetime_corr.inputs.tr = '1.76'
slicetime_corr.inputs.interp = 'quintic'
slicetime_corr.inputs.slice_timing = slice_timing_list
slicetime_corr.inputs.outputtype = 'NIFTI_GZ'
psb6351_wf.connect(maskfunc, 'out_file', slicetime_corr, 'in_file')


#HW; Adding motion-corrected and slice-timing files to spatial blurring node. 
#My understanding is that spatial blurring averages over nearby voxels to obtain a Gaussian-like BOLD signal
#Since parametric statistic tests asuume normal distribution
#Thus, applying spatial filtering to functional data where voxels have been shifted to ensure signals 
#are in the correct spatial location and signal has been temporally shifted for a more time accurate signal may be an adequate choice
spatial_blur = pe.MapNode(afni.Merge(),
                  iterfield=['in_files'],
                  name = 'spatial_blur')
spatial_blur.inputs.blurfwhm = 4 # Recommeded standard dev for single subject; 6 recommended for multi-subject to account for individual variation
spatial_blur.inputs.doall = True
spatial_blur.inputs.outputtype = 'NIFTI_GZ'
psb6351_wf.connect(slicetime_corr, 'out_file', spatial_blur, 'in_files')


align = pe.MapNode(afni.AlignEpiAnatPy(), iterfield =['in_file'], name = 'align')
align.inputs.anat = '/scratch/dsmit216/mattfeld/psb6351workdir/sub-021/psb6351_wf/maskanat/mapflow/_maskanat0/sub-021_run-1_T1w_bet.nii.gz'
align.inputs.epi_base = 'mean'
align.inputs.epi_strip = 'None'
align.inputs.volreg = 'off'
align.inputs.tshift = 'off'
align.inputs.outputtype = 'NIFTI_GZ'
psb6351_wf.connect(spatial_blur, 'out_file', align, 'in_file')

datasink = pe.Node(nio.DataSink(), name="datasink")
datasink.inputs.base_directory = os.path.join(base_dir, 'derivatives/preproc1')
datasink.inputs.container = f'sub-021'
psb6351_wf.connect(getsubs, 'subs', datasink, 'substitutions')
psb6351_wf.connect(meanfunc, 'out_file', datasink, 'firstvolfuncmean')
psb6351_wf.connect(meanfuncmask, 'mask_file', datasink, 'firstvolfuncmeanmask')
psb6351_wf.connect(maskfunc, 'out_file', datasink, 'funcmaskfiles')
psb6351_wf.connect(meananat, 'out_file', datasink, 'firstvolanatmean')
psb6351_wf.connect(meananatmask, 'mask_file', datasink, 'firstvolanatmeanmask')
psb6351_wf.connect(maskanat, 'out_file', datasink, 'anatmaskfiles')
psb6351_wf.connect(motion_corr, 'out_file', datasink, 'motion.@corrfile')
psb6351_wf.connect(motion_corr, 'mat_file', datasink, 'motion.@matrix')
psb6351_wf.connect(motion_corr, 'par_file', datasink, 'motion.@par')
psb6351_wf.connect(slicetime_corr, 'out_file', datasink, 'sltime_corr')
psb6351_wf.connect(align, 'epi_al_mat', datasink, 'align.@matrixepi2anat')
psb6351_wf.connect(align, 'epi_al_tlrc_mat', datasink, 'align.@tlrc_mat')
#psb6351_wf.connect(align, 'epi_vr_al_mat ', datasink, 'align.@matrixepi2anat')
psb6351_wf.connect(align, 'epi_al_orig', datasink, 'align.@alignedepi2anat')
psb6351_wf.connect(align, 'epi_tlrc_al', datasink, 'align.@alignedepiandtlrc')
psb6351_wf.connect(align, 'epi_reg_al_mat', datasink, 'align.@epi_reg_al_mat')
psb6351_wf.connect(artifacts, 'statistic_files', datasink, 'artifacts.@stats')
psb6351_wf.connect(artifacts, 'displacement_files', datasink, 'artifacts.@dis')
psb6351_wf.connect(spatial_blur, 'out_file', datasink, 'spatial.blur')
psb6351_wf.run(plugin='SLURM',
               plugin_args={'sbatch_args': ('--partition centos7_default-partition --qos pq_psb6351 --account acc_psb6351'),
                            'overwrite':True})
# Out:
# 201119-18:05:43,206 nipype.workflow INFO:
# 	 Workflow psb6351_wf settings: ['check', 'execution', 'logging', 'monitoring']
# 201119-18:05:43,226 nipype.workflow INFO:
# 	 Running in parallel.
# 201119-18:05:43,231 nipype.workflow INFO:
# 	 Pending[0] Submitting[3] jobs Slots[inf]
# 201119-18:05:43,232 nipype.workflow INFO:
# 	 Submitting: psb6351_wf.getsubs ID: 0
# 201119-18:05:43,233 nipype.workflow INFO:
# 	 [Job 0] Cached (psb6351_wf.getsubs).
# 201119-18:05:43,235 nipype.workflow INFO:
# 	 Finished submitting: psb6351_wf.getsubs ID: 0
# 201119-18:05:43,236 nipype.workflow INFO:
# 	 Submitting: psb6351_wf.meananat ID: 1
# 201119-18:05:43,238 nipype.workflow INFO:
# 	 [Job 1] Cached (psb6351_wf.meananat).
# 201119-18:05:43,240 nipype.workflow INFO:
# 	 Finished submitting: psb6351_wf.meananat ID: 1
# 201119-18:05:43,255 nipype.workflow INFO:
# 	 Pending[0] Submitting[7] jobs Slots[inf]
# 201119-18:05:43,257 nipype.workflow INFO:
# 	 Submitting: psb6351_wf.meananatmask ID: 2
# 201119-18:05:43,260 nipype.workflow INFO:
# 	 [Job 2] Cached (psb6351_wf.meananatmask).
# 201119-18:05:43,262 nipype.workflow INFO:
# 	 Finished submitting: psb6351_wf.meananatmask ID: 2
# 201119-18:05:43,262 nipype.workflow INFO:
# 	 Submitting: _motion_corr0 ID: 13
# 201119-18:05:43,265 nipype.workflow INFO:
# 	 [Job 13] Cached (_motion_corr0).
# 201119-18:05:43,266 nipype.workflow INFO:
# 	 Finished submitting: _motion_corr0 ID: 13
# 201119-18:05:43,267 nipype.workflow INFO:
# 	 Submitting: _motion_corr1 ID: 14
# 201119-18:05:43,269 nipype.workflow INFO:
# 	 [Job 14] Cached (_motion_corr1).
# 201119-18:05:43,270 nipype.workflow INFO:
# 	 Finished submitting: _motion_corr1 ID: 14
# 201119-18:05:43,271 nipype.workflow INFO:
# 	 Submitting: _motion_corr2 ID: 15
# 201119-18:05:43,273 nipype.workflow INFO:
# 	 [Job 15] Cached (_motion_corr2).
# 201119-18:05:43,275 nipype.workflow INFO:
# 	 Finished submitting: _motion_corr2 ID: 15
# 201119-18:05:43,275 nipype.workflow INFO:
# 	 Submitting: _motion_corr3 ID: 16
# 201119-18:05:43,278 nipype.workflow INFO:
# 	 [Job 16] Cached (_motion_corr3).
# 201119-18:05:43,279 nipype.workflow INFO:
# 	 Finished submitting: _motion_corr3 ID: 16
# 201119-18:05:43,280 nipype.workflow INFO:
# 	 Submitting: _motion_corr4 ID: 17
# 201119-18:05:43,282 nipype.workflow INFO:
# 	 [Job 17] Cached (_motion_corr4).
# 201119-18:05:43,283 nipype.workflow INFO:
# 	 Finished submitting: _motion_corr4 ID: 17
# 201119-18:05:43,284 nipype.workflow INFO:
# 	 Submitting: _motion_corr5 ID: 18
# 201119-18:05:43,286 nipype.workflow INFO:
# 	 [Job 18] Cached (_motion_corr5).
# 201119-18:05:43,287 nipype.workflow INFO:
# 	 Finished submitting: _motion_corr5 ID: 18
# 201119-18:05:43,289 nipype.workflow INFO:
# 	 Pending[0] Submitting[2] jobs Slots[inf]
# 201119-18:05:43,293 nipype.workflow INFO:
# 	 Submitting: psb6351_wf.maskanat ID: 3
# 201119-18:05:43,296 nipype.workflow INFO:
# 	 [Job 3] Cached (psb6351_wf.maskanat).
# 201119-18:05:43,297 nipype.workflow INFO:
# 	 Finished submitting: psb6351_wf.maskanat ID: 3
# 201119-18:05:43,300 nipype.workflow INFO:
# 	 Submitting: psb6351_wf.motion_corr ID: 4
# 201119-18:05:43,304 nipype.workflow INFO:
# 	 [Job 4] Cached (psb6351_wf.motion_corr).
# 201119-18:05:43,306 nipype.workflow INFO:
# 	 Finished submitting: psb6351_wf.motion_corr ID: 4
# 201119-18:05:43,307 nipype.workflow INFO:
# 	 Pending[0] Submitting[1] jobs Slots[inf]
# 201119-18:05:43,308 nipype.workflow INFO:
# 	 Submitting: psb6351_wf.meanfunc ID: 5
# 201119-18:05:43,314 nipype.workflow INFO:
# 	 [Job 5] Cached (psb6351_wf.meanfunc).
# 201119-18:05:43,316 nipype.workflow INFO:
# 	 Finished submitting: psb6351_wf.meanfunc ID: 5
# 201119-18:05:43,318 nipype.workflow INFO:
# 	 Pending[0] Submitting[1] jobs Slots[inf]
# 201119-18:05:43,319 nipype.workflow INFO:
# 	 Submitting: psb6351_wf.meanfuncmask ID: 6
# 201119-18:05:43,322 nipype.workflow INFO:
# 	 [Job 6] Cached (psb6351_wf.meanfuncmask).
# 201119-18:05:43,323 nipype.workflow INFO:
# 	 Finished submitting: psb6351_wf.meanfuncmask ID: 6
# 201119-18:05:43,325 nipype.workflow INFO:
# 	 Pending[0] Submitting[1] jobs Slots[inf]
# 201119-18:05:43,343 nipype.workflow INFO:
# 	 Pending[0] Submitting[6] jobs Slots[inf]
# 201119-18:05:43,344 nipype.workflow INFO:
# 	 Submitting: _maskfunc0 ID: 19
# 201119-18:05:43,346 nipype.workflow INFO:
# 	 [Job 19] Cached (_maskfunc0).
# 201119-18:05:43,348 nipype.workflow INFO:
# 	 Finished submitting: _maskfunc0 ID: 19
# 201119-18:05:43,349 nipype.workflow INFO:
# 	 Submitting: _maskfunc1 ID: 20
# 201119-18:05:43,351 nipype.workflow INFO:
# 	 [Job 20] Cached (_maskfunc1).
# 201119-18:05:43,352 nipype.workflow INFO:
# 	 Finished submitting: _maskfunc1 ID: 20
# 201119-18:05:43,353 nipype.workflow INFO:
# 	 Submitting: _maskfunc2 ID: 21
# 201119-18:05:43,355 nipype.workflow INFO:
# 	 [Job 21] Cached (_maskfunc2).
# 201119-18:05:43,356 nipype.workflow INFO:
# 	 Finished submitting: _maskfunc2 ID: 21
# 201119-18:05:43,357 nipype.workflow INFO:
# 	 Submitting: _maskfunc3 ID: 22
# 201119-18:05:43,360 nipype.workflow INFO:
# 	 [Job 22] Cached (_maskfunc3).
# 201119-18:05:43,361 nipype.workflow INFO:
# 	 Finished submitting: _maskfunc3 ID: 22
# 201119-18:05:43,362 nipype.workflow INFO:
# 	 Submitting: _maskfunc4 ID: 23
# 201119-18:05:43,364 nipype.workflow INFO:
# 	 [Job 23] Cached (_maskfunc4).
# 201119-18:05:43,365 nipype.workflow INFO:
# 	 Finished submitting: _maskfunc4 ID: 23
# 201119-18:05:43,366 nipype.workflow INFO:
# 	 Submitting: _maskfunc5 ID: 24
# 201119-18:05:43,368 nipype.workflow INFO:
# 	 [Job 24] Cached (_maskfunc5).
# 201119-18:05:43,369 nipype.workflow INFO:
# 	 Finished submitting: _maskfunc5 ID: 24
# 201119-18:05:43,371 nipype.workflow INFO:
# 	 Pending[0] Submitting[1] jobs Slots[inf]
# 201119-18:05:43,374 nipype.workflow INFO:
# 	 Submitting: psb6351_wf.maskfunc ID: 7
# 201119-18:05:43,377 nipype.workflow INFO:
# 	 [Job 7] Cached (psb6351_wf.maskfunc).
# 201119-18:05:43,379 nipype.workflow INFO:
# 	 Finished submitting: psb6351_wf.maskfunc ID: 7
# 201119-18:05:43,381 nipype.workflow INFO:
# 	 Pending[0] Submitting[2] jobs Slots[inf]
# 201119-18:05:43,420 nipype.workflow INFO:
# 	 Pending[0] Submitting[12] jobs Slots[inf]
# 201119-18:05:43,421 nipype.workflow INFO:
# 	 Submitting: _slicetime_corr0 ID: 25
# 201119-18:05:43,423 nipype.workflow INFO:
# 	 [Job 25] Cached (_slicetime_corr0).
# 201119-18:05:43,425 nipype.workflow INFO:
# 	 Finished submitting: _slicetime_corr0 ID: 25
# 201119-18:05:43,425 nipype.workflow INFO:
# 	 Submitting: _slicetime_corr1 ID: 26
# 201119-18:05:43,428 nipype.workflow INFO:
# 	 [Job 26] Cached (_slicetime_corr1).
# 201119-18:05:43,429 nipype.workflow INFO:
# 	 Finished submitting: _slicetime_corr1 ID: 26
# 201119-18:05:43,430 nipype.workflow INFO:
# 	 Submitting: _slicetime_corr2 ID: 27
# 201119-18:05:43,433 nipype.workflow INFO:
# 	 [Job 27] Cached (_slicetime_corr2).
# 201119-18:05:43,434 nipype.workflow INFO:
# 	 Finished submitting: _slicetime_corr2 ID: 27
# 201119-18:05:43,435 nipype.workflow INFO:
# 	 Submitting: _slicetime_corr3 ID: 28
# 201119-18:05:43,437 nipype.workflow INFO:
# 	 [Job 28] Cached (_slicetime_corr3).
# 201119-18:05:43,439 nipype.workflow INFO:
# 	 Finished submitting: _slicetime_corr3 ID: 28
# 201119-18:05:43,440 nipype.workflow INFO:
# 	 Submitting: _slicetime_corr4 ID: 29
# 201119-18:05:43,442 nipype.workflow INFO:
# 	 [Job 29] Cached (_slicetime_corr4).
# 201119-18:05:43,443 nipype.workflow INFO:
# 	 Finished submitting: _slicetime_corr4 ID: 29
# 201119-18:05:43,444 nipype.workflow INFO:
# 	 Submitting: _slicetime_corr5 ID: 30
# 201119-18:05:43,447 nipype.workflow INFO:
# 	 [Job 30] Cached (_slicetime_corr5).
# 201119-18:05:43,448 nipype.workflow INFO:
# 	 Finished submitting: _slicetime_corr5 ID: 30
# 201119-18:05:43,449 nipype.workflow INFO:
# 	 Submitting: _artifacts0 ID: 31
# 201119-18:05:43,451 nipype.workflow INFO:
# 	 [Job 31] Cached (_artifacts0).
# 201119-18:05:43,452 nipype.workflow INFO:
# 	 Finished submitting: _artifacts0 ID: 31
# 201119-18:05:43,453 nipype.workflow INFO:
# 	 Submitting: _artifacts1 ID: 32
# 201119-18:05:43,456 nipype.workflow INFO:
# 	 [Job 32] Cached (_artifacts1).
# 201119-18:05:43,457 nipype.workflow INFO:
# 	 Finished submitting: _artifacts1 ID: 32
# 201119-18:05:43,458 nipype.workflow INFO:
# 	 Submitting: _artifacts2 ID: 33
# 201119-18:05:43,460 nipype.workflow INFO:
# 	 [Job 33] Cached (_artifacts2).
# 201119-18:05:43,462 nipype.workflow INFO:
# 	 Finished submitting: _artifacts2 ID: 33
# 201119-18:05:43,462 nipype.workflow INFO:
# 	 Submitting: _artifacts3 ID: 34
# 201119-18:05:43,465 nipype.workflow INFO:
# 	 [Job 34] Cached (_artifacts3).
# 201119-18:05:43,466 nipype.workflow INFO:
# 	 Finished submitting: _artifacts3 ID: 34
# 201119-18:05:43,467 nipype.workflow INFO:
# 	 Submitting: _artifacts4 ID: 35
# 201119-18:05:43,470 nipype.workflow INFO:
# 	 [Job 35] Cached (_artifacts4).
# 201119-18:05:43,471 nipype.workflow INFO:
# 	 Finished submitting: _artifacts4 ID: 35
# 201119-18:05:43,472 nipype.workflow INFO:
# 	 Submitting: _artifacts5 ID: 36
# 201119-18:05:43,475 nipype.workflow INFO:
# 	 [Job 36] Cached (_artifacts5).
# 201119-18:05:43,477 nipype.workflow INFO:
# 	 Finished submitting: _artifacts5 ID: 36
# 201119-18:05:43,479 nipype.workflow INFO:
# 	 Pending[0] Submitting[2] jobs Slots[inf]
# 201119-18:05:43,484 nipype.workflow INFO:
# 	 Submitting: psb6351_wf.slicetime_corr ID: 8
# 201119-18:05:43,493 nipype.workflow INFO:
# 	 [Job 8] Cached (psb6351_wf.slicetime_corr).
# 201119-18:05:43,496 nipype.workflow INFO:
# 	 Finished submitting: psb6351_wf.slicetime_corr ID: 8
# 201119-18:05:43,499 nipype.workflow INFO:
# 	 Submitting: psb6351_wf.artifacts ID: 11
# 201119-18:05:43,505 nipype.workflow INFO:
# 	 [Job 11] Cached (psb6351_wf.artifacts).
# 201119-18:05:43,507 nipype.workflow INFO:
# 	 Finished submitting: psb6351_wf.artifacts ID: 11
# 201119-18:05:43,509 nipype.workflow INFO:
# 	 Pending[0] Submitting[1] jobs Slots[inf]
# 201119-18:05:43,531 nipype.workflow INFO:
# 	 Pending[0] Submitting[6] jobs Slots[inf]
# 201119-18:05:43,531 nipype.workflow INFO:
# 	 Submitting: _spatial_blur0 ID: 37
# 201119-18:05:43,765 nipype.workflow INFO:
# 	 Finished submitting: _spatial_blur0 ID: 37
# 201119-18:05:43,766 nipype.workflow INFO:
# 	 Submitting: _spatial_blur1 ID: 38
# 201119-18:05:43,977 nipype.workflow INFO:
# 	 Finished submitting: _spatial_blur1 ID: 38
# 201119-18:05:43,978 nipype.workflow INFO:
# 	 Submitting: _spatial_blur2 ID: 39
# 201119-18:05:44,188 nipype.workflow INFO:
# 	 Finished submitting: _spatial_blur2 ID: 39
# 201119-18:05:44,190 nipype.workflow INFO:
# 	 Submitting: _spatial_blur3 ID: 40
# 201119-18:05:44,393 nipype.workflow INFO:
# 	 Finished submitting: _spatial_blur3 ID: 40
# 201119-18:05:44,395 nipype.workflow INFO:
# 	 Submitting: _spatial_blur4 ID: 41
# 201119-18:05:44,609 nipype.workflow INFO:
# 	 Finished submitting: _spatial_blur4 ID: 41
# 201119-18:05:44,611 nipype.workflow INFO:
# 	 Submitting: _spatial_blur5 ID: 42
# 201119-18:05:44,828 nipype.workflow INFO:
# 	 Finished submitting: _spatial_blur5 ID: 42
# 201119-18:06:23,527 nipype.workflow INFO:
# 	 [Job 37] Completed (_spatial_blur0).
# 201119-18:06:23,756 nipype.workflow INFO:
# 	 [Job 38] Completed (_spatial_blur1).
# 201119-18:06:29,553 nipype.workflow INFO:
# 	 [Job 39] Completed (_spatial_blur2).
# 201119-18:06:29,779 nipype.workflow INFO:
# 	 [Job 40] Completed (_spatial_blur3).
# 201119-18:06:29,997 nipype.workflow INFO:
# 	 [Job 41] Completed (_spatial_blur4).
# 201119-18:06:33,561 nipype.workflow INFO:
# 	 [Job 42] Completed (_spatial_blur5).
# 201119-18:06:33,565 nipype.workflow INFO:
# 	 Pending[0] Submitting[1] jobs Slots[inf]
# 201119-18:06:33,569 nipype.workflow INFO:
# 	 Submitting: psb6351_wf.spatial_blur ID: 9
# 201119-18:06:33,789 nipype.workflow INFO:
# 	 Finished submitting: psb6351_wf.spatial_blur ID: 9
# 201119-18:06:35,591 nipype.workflow INFO:
# 	 [Job 9] Completed (psb6351_wf.spatial_blur).
# 201119-18:06:35,595 nipype.workflow INFO:
# 	 Pending[0] Submitting[1] jobs Slots[inf]
# 201119-18:06:35,613 nipype.workflow INFO:
# 	 Pending[0] Submitting[6] jobs Slots[inf]
# 201119-18:06:35,613 nipype.workflow INFO:
# 	 Submitting: _align0 ID: 43
# 201119-18:06:35,618 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "_align0".
# 201119-18:06:35,840 nipype.workflow INFO:
# 	 Finished submitting: _align0 ID: 43
# 201119-18:06:35,841 nipype.workflow INFO:
# 	 Submitting: _align1 ID: 44
# 201119-18:06:35,845 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "_align1".
# 201119-18:06:36,65 nipype.workflow INFO:
# 	 Finished submitting: _align1 ID: 44
# 201119-18:06:36,67 nipype.workflow INFO:
# 	 Submitting: _align2 ID: 45
# 201119-18:06:36,71 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "_align2".
# 201119-18:06:36,294 nipype.workflow INFO:
# 	 Finished submitting: _align2 ID: 45
# 201119-18:06:36,296 nipype.workflow INFO:
# 	 Submitting: _align3 ID: 46
# 201119-18:06:36,301 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "_align3".
# 201119-18:06:36,508 nipype.workflow INFO:
# 	 Finished submitting: _align3 ID: 46
# 201119-18:06:36,509 nipype.workflow INFO:
# 	 Submitting: _align4 ID: 47
# 201119-18:06:36,515 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "_align4".
# 201119-18:06:36,730 nipype.workflow INFO:
# 	 Finished submitting: _align4 ID: 47
# 201119-18:06:36,732 nipype.workflow INFO:
# 	 Submitting: _align5 ID: 48
# 201119-18:06:36,739 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "_align5".
# 201119-18:06:36,959 nipype.workflow INFO:
# 	 Finished submitting: _align5 ID: 48
# 201119-18:12:22,291 nipype.workflow INFO:
# 	 [Job 43] Completed (_align0).
# 201119-18:12:38,529 nipype.workflow INFO:
# 	 [Job 45] Completed (_align2).
# 201119-18:12:42,310 nipype.workflow INFO:
# 	 [Job 44] Completed (_align1).
# 201119-18:12:42,728 nipype.workflow INFO:
# 	 [Job 47] Completed (_align4).
# 201119-18:13:20,475 nipype.workflow INFO:
# 	 [Job 46] Completed (_align3).
# 201119-18:13:48,616 nipype.workflow INFO:
# 	 [Job 48] Completed (_align5).
# 201119-18:13:48,621 nipype.workflow INFO:
# 	 Pending[0] Submitting[1] jobs Slots[inf]
# 201119-18:13:48,627 nipype.workflow INFO:
# 	 Submitting: psb6351_wf.align ID: 10
# 201119-18:13:48,634 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "psb6351_wf.align".
# 201119-18:13:48,863 nipype.workflow INFO:
# 	 Finished submitting: psb6351_wf.align ID: 10
# 201119-18:13:52,625 nipype.workflow INFO:
# 	 [Job 10] Completed (psb6351_wf.align).
# 201119-18:13:52,629 nipype.workflow INFO:
# 	 Pending[0] Submitting[1] jobs Slots[inf]
# 201119-18:13:52,630 nipype.workflow INFO:
# 	 Submitting: psb6351_wf.datasink ID: 12
# 201119-18:13:57,473 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "psb6351_wf.datasink".
# 201119-18:13:57,725 nipype.workflow INFO:
# 	 Finished submitting: psb6351_wf.datasink ID: 12
# 201119-18:15:10,282 nipype.workflow INFO:
# 	 [Job 12] Completed (psb6351_wf.datasink).
